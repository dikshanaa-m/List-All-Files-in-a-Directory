# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshanaa-m/List-All-Files-in-a-Directory/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
files = os.listdir('.')
print(f"Files in current folder: {files}")
# Out:
# Files in current folder: ['.config', 'sample_data']
